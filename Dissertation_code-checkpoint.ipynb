# %% [markdown]
# # Setup

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Reading the Data and EDA

# %%
data = pd.read_csv("housing_in_london_monthly_variables.csv", infer_datetime_format=True)

# %% [markdown]
# Take a Quick Look at the Data Structure

# %%
print(data.head())
print(data.info())
# Out:
#          date            area  average_price       code  houses_sold  \
# 0  1995-01-01  city of london          91449  E09000001         17.0
# 1  1995-02-01  city of london          82203  E09000001          7.0
# 2  1995-03-01  city of london          79121  E09000001         14.0
# 3  1995-04-01  city of london          77101  E09000001          7.0
# 4  1995-05-01  city of london          84409  E09000001         10.0
#
#    no_of_crimes  borough_flag
# 0           NaN             1
# 1           NaN             1
# 2           NaN             1
# 3           NaN             1
# 4           NaN             1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13549 entries, 0 to 13548
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           13549 non-null  object
#  1   area           13549 non-null  object
#  2   average_price  13549 non-null  int64
#  3   code           13549 non-null  object
#  4   houses_sold    13455 non-null  float64
#  5   no_of_crimes   7439 non-null   float64
#  6   borough_flag   13549 non-null  int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 741.1+ KB
# None

# %%
# convert date from object Dtype to datetime Dtype
data.date = pd.to_datetime(data.date)

# %% [markdown]
# Missing Data

# %%
# count missing values
print("House_sold Missing :", data['houses_sold'].isna().sum())
print("Crimes Missing :", data['no_of_crimes'].isna().sum())
# Out:
# House_sold Missing : 94
# Crimes Missing : 6110

# %%
# view missing data as a table
data[data['houses_sold'].isna()].head(3)
# Out:
#           date                  area  average_price       code  houses_sold  \
# 299 2019-12-01        city of london         734872  E09000001          NaN
# 300 2020-01-01        city of london         775309  E09000001          NaN
# 600 2019-12-01  barking and dagenham         301816  E09000002          NaN
#
#      no_of_crimes  borough_flag
# 299           NaN             1
# 300           NaN             1
# 600        1659.0             1

# %%
# rows with both NaN for houses_sold and no_of_crimes
data[(data['houses_sold'].isna()) & (data['no_of_crimes'].isna())].head(5)
# Out:
#            date            area  average_price       code  houses_sold  \
# 299  2019-12-01  city of london         734872  E09000001          NaN
# 300  2020-01-01  city of london         775309  E09000001          NaN
# 2723 1996-02-01         enfield          71070  E09000030          NaN
# 2724 1996-02-01   tower hamlets          71070  E09000010          NaN
# 3354 1998-04-01         hackney          83176  E12000008          NaN
#
#       no_of_crimes  borough_flag
# 299            NaN             1
# 300            NaN             1
# 2723           NaN             1
# 2724           NaN             1
# 3354           NaN             1

# %% [markdown]
# Numerical Columns and Value Counts for Categorical Columns

# %%
# summary statistics for numerical values
data.describe()
# Out:
#        average_price    houses_sold  no_of_crimes  borough_flag
# count   1.354900e+04   13455.000000   7439.000000  13549.000000
# mean    2.635197e+05    3893.994129   2158.352063      0.733338
# std     1.876175e+05   12114.402476    902.087742      0.442230
# min     4.072200e+04       2.000000      0.000000      0.000000
# 25%     1.323800e+05     247.000000   1623.000000      0.000000
# 50%     2.229190e+05     371.000000   2132.000000      1.000000
# 75%     3.368430e+05    3146.000000   2582.000000      1.000000
# max     1.463378e+06  132163.000000   7461.000000      1.000000

# %%
# value counts for categorical values
print(data['area'].value_counts())
print(data['borough_flag'].value_counts())
print(data['date'].min(), data['date'].max())
# Out:
# hackney                   302
# south east                302
# enfield                   302
# tower hamlets             302
# redbridge                 301
# richmond upon thames      301
# southwark                 301
# sutton                    301
# waltham forest            301
# wandsworth                301
# westminster               301
# inner london              301
# outer london              301
# city of london            301
# merton                    301
# north east                301
# north west                301
# yorks and the humber      301
# east midlands             301
# west midlands             301
# east of england           301
# london                    301
# south west                301
# newham                    301
# kingston upon thames      301
# lewisham                  301
# lambeth                   301
# barnet                    301
# bexley                    301
# brent                     301
# bromley                   301
# camden                    301
# croydon                   301
# ealing                    301
# greenwich                 301
# hammersmith and fulham    301
# haringey                  301
# harrow                    301
# havering                  301
# hillingdon                301
# hounslow                  301
# islington                 301
# kensington and chelsea    301
# barking and dagenham      301
# england                   301
# Name: area, dtype: int64
# 1    9936
# 0    3613
# Name: borough_flag, dtype: int64
# 1995-01-01 00:00:00 2020-01-01 00:00:00

# %% [markdown]
# EDA and Visualizations

# %%
data.hist(figsize=(15,10)) #the dimensions of the plot in inches
plt.show()

# %% [markdown]
# Deeper look at houses_sold histogram

# %%
# change the range to 0 to 25000 for houses_sold
data['houses_sold'].hist(range=(0,25000))
# Out:
# <Axes: >

# %%
data.plot(kind= 'scatter',
          x='average_price',
          y ='houses_sold',
          alpha=.1,
          c= data['no_of_crimes'],
          cmap=plt.get_cmap('jet'),
          colorbar=True,
          figsize=(9,4),
          sharex=False)
plt.title('Houses Sold and Average Price Against Number of Crimes')
# Out:
# Text(0.5, 1.0, 'Houses Sold and Average Price Against Number of Crimes')

# %%
# correlations
corr_matrix = data.corr()
corr_matrix['average_price'].sort_values(ascending=False)
# Out:
# <ipython-input-17-3f26bdee3dff>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = data.corr()
# average_price    1.000000
# borough_flag     0.293271
# no_of_crimes     0.113835
# houses_sold     -0.168256
# Name: average_price, dtype: float64

# %% [markdown]
# Handling the Date Column

# %%
data['year'] = data['date'].dt.year
data['month']= data['date'].dt.month

# %%
data.head()
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
# 2 1995-03-01  city of london          79121  E09000001         14.0
# 3 1995-04-01  city of london          77101  E09000001          7.0
# 4 1995-05-01  city of london          84409  E09000001         10.0
#
#    no_of_crimes  borough_flag  year  month
# 0           NaN             1  1995      1
# 1           NaN             1  1995      2
# 2           NaN             1  1995      3
# 3           NaN             1  1995      4
# 4           NaN             1  1995      5

# %%
# correlation of average prices with day and month
yr_corr=data['average_price'].corr(data['year'])
mon_corr = data['average_price'].corr(data['month'])
print(' Year and Avg.Price Correlation:', yr_corr, '\n','Month and Avg. Price Correlation:', mon_corr)
# Out:
#  Year and Avg.Price Correlation: 0.6640450565926829
#  Month and Avg. Price Correlation: 0.023212514469309924

# %%
data.plot(kind= 'scatter',
          x='average_price',
          y ='houses_sold',
          s = data['no_of_crimes']/10,
          alpha=.1,
          label='number of crimes',
          c= data['year'],
          cmap=plt.get_cmap('jet'),
          colorbar=True,
          figsize=(9,4),
          sharex=False)
# Out:
# <Axes: xlabel='average_price', ylabel='houses_sold'>

# %% [markdown]
# # Split the Data

# %%
# make copy first
df_copy = data.copy()
